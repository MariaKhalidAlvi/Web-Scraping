# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
cricketTableData_df = pd.read_csv("CricketTest_TableData.csv")

# %%
cricketTableData_df.head(50)
# Out:
#    average       country highestInningScore inningsBatted  matchesPlayes  \
# 0    53.78       (INDIA)               248*           329            200
# 1    51.85         (AUS)                257           287            168
# 2    55.37      (ICC/SA)                224           280            166
# 3    52.31   (ICC/INDIA)                270           286            164
# 4    45.35         (ENG)                294           291            161
# 5    57.40          (SL)                319           233            134
# 6    52.88      (ICC/WI)               400*           232            131
# 7    51.37          (WI)               203*           280            164
# 8    49.84          (SL)                374           252            149
# 9    50.56         (AUS)                205           265            156
# 10   51.06         (AUS)                200           260            168
# 11   51.12       (INDIA)               236*           214            125
# ...
